# %%
# 선형회귀

# %%
from sklearn.linear_model import LinearRegression

# 특징
x = [[10.0], [8.0], [13.0], [9.0], [11.0], [14.0],
     [6.0], [4.0], [12.0], [7.0], [5.0]]

# 종속 변수
y = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96,
     7.24, 4.26, 10.84, 4.82, 5.68]

# 선형회귀 모델 생성, 학습
model = LinearRegression()
model.fit(x,y)

print(model.coef_) # 기울기 출력
print(model.intercept_) # 절편 출력

# 회귀식 : y = 0.50009091 x + 3.0000909090909094
# Out:
# [0.50009091]
# 3.0000909090909094

# %%
# 정규화
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# 학습 데이터 개수 설정
train_size = 20

# 검정 데이터 개수 설정
test_size = 12

# 학습 및 검정 데이터 특징으로 사용할 무작위 표본 추출
train_x = np.random.uniform(low=0, high=1.2, size=train_size)
test_x = np.random.uniform(low=0.1, high=1.3, size=test_size)

# 학습 및 검정 데이터 종속 변수로 사용할 데이터 정의
train_y = np.sin(train_x * 2 * np.pi) + np.random.normal(0, 0.2, train_size)
test_y = np.sin(test_x * 2 * np.pi) + np.random.normal(0, 0.2, test_size)

poly = PolynomialFeatures(6) # 6차식
print(poly)
# Out:
# PolynomialFeatures(degree=6)

# %%
# 6차식에서 학습 데이터 특징으로 학습 >> 결과를 배열로 변환
# 정교화
train_ploy_x = poly.fit_transform(train_x.reshape(train_size, 1))
test_ploy_x = poly.fit_transform(test_x.reshape(test_size, 1))

# %%
# Ridge 모델 생성 >> 6차식 학습결과와 학습 데이터 종속변수로 학습

model = Ridge(alpha=1.0)
model.fit(train_ploy_x, train_y)
# fit() train data 로 한다 >> 왜? 모델을 구축 test 데이터는 검증해야하니 보관.
# Out:
# Ridge()

# %%
# 모델 활용, 예측

train_pred_y = model.predict(train_ploy_x) # y_hat : 예측한 값
test_pred_y = model.predict(test_ploy_x)

# %%
# 학습 데이터와 검증 데이터를 대상으로 예측한 결과
# 평균제곱오차 계산

print(mean_squared_error(train_pred_y, train_y))
print(mean_squared_error(test_pred_y, test_y))
# Out:
# 0.23776810549099067
# 0.32936112600836204

# %% [markdown]
# 로지스틱 회귀

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# 특징 데이터 생성
x_train = np.r_[np.random.normal(3, 1, size=50),
      np.random.normal(-1, 1, size=50)].reshape((100,-1))

# np.random.normal (평균, 표준편차, 난수로 만든 데이터 개수)
# 정규분포 (평균 0, 표준편차 1)
# np.r_ : 두 배열을 수평 결합

# 종속 변수 (y값) 변수 데이터 생성

y_train = np.r_[np.ones(50), np.zeros(50)]

# 로지스틱 회귀 모델 생성 및 학습과 예측

model = LogisticRegression(solver='lbfgs')

# fit() 반드시 train data 로 한다.
model.fit(x_train, y_train)


# 예측
model.predict_proba([[0],[1],[2]])[:, 1]
# Out:
# array([0.13045449, 0.63370753, 0.95226857])
